# %%
import numpy as np

# %%
array = np.array([1,2,3,4,5])

# %%
print(type(array))

# %%
print(array)
print(array.dtype)

# %%
array = np.array([1,2,3,4,5] , dtype = np.int8)

# %%
print(array.dtype)

# %%
print(array)
print(array.dtype)
print(array.nbytes)

# %%
print(array)
print(array.dtype)
print(array.nbytes)
print(f"{array.nbytes}bytes")

# %%
array= np.array([129,2,3,4,5] ,dtype=np.int8)

# %%
array= np.array([129,2,3,4,5] ,dtype=np.int16)

# %%
print(array)
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array=np.array([1.2,3.4,5.3,4.7,5.0])

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array= np.array([129,200,300,500,500] ,dtype=np.str_)

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array= np.array([129,2000,300,500,500] ,dtype=np.str_)

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array = np.array(["come","go","Game","play"])

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array= np.array([True,False,True])

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array= np.array([True,False,True],dtype=np.bool_)

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array=np.array([1,2,3,4,5])

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array = array.astype(np.str_)

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")

# %%
array = array.astype(np.bool_)

# %%
print(array)
print(type(array))
print(array.dtype)
print(f"{array.nbytes}bytes")
